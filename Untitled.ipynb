# %% [markdown]
# # Interrogate parcels regarding its lazyness

# %%
import xarray as xr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b027d314c3e9> in <module>
# ----> 1 import xarray as xr
#
# ~/miniconda/envs/py3_parcels/lib/python3.7/site-packages/xarray/__init__.py in <module>
#       1 import pkg_resources
#       2
# ----> 3 from . import testing, tutorial, ufuncs
#       4 from .backends.api import (
#       5     load_dataarray,
#
# ~/miniconda/envs/py3_parcels/lib/python3.7/site-packages/xarray/testing.py in <module>
#       4
#       5 import numpy as np
# ----> 6 import pandas as pd
#       7
#       8 from xarray.core import duck_array_ops, formatting, utils
#
# ~/miniconda/envs/py3_parcels/lib/python3.7/site-packages/pandas/__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat.numpy import (
#      23     _np_version_under1p16,
#      24     _np_version_under1p17,
#
# ...

# %%
ds = xr.open_zarr('test_data/local_test_dataset.zarr', consolidated=True)

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6f4a4004dcca> in <module>
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %% [markdown]
# It seemed to have worked with ...'2.0.0b3.dev104+gb7e906b6'

# %%
import parcels
parcels.__version__
# Out:
# '2.2.2.dev141+g4da6ea5c'

# %%
from parcels import FieldSet, AdvectionRK4, ParticleSet, JITParticle, ParticleFile
from parcels import plotTrajectoriesFile
import numpy as np
import xarray as xr
import gcsfs
from datetime import timedelta as delta

from dask import array as da
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-d04402c4e864> in <module>
#       3 import numpy as np
#       4 import xarray as xr
# ----> 5 import gcsfs
#       6 from datetime import timedelta as delta
#       7
#
# ModuleNotFoundError: No module named 'gcsfs'

# %% [markdown]
# ## First step: Make creating a fieldset lazy

# %% [markdown]
# Replace the velocity data with the fake warning and see if anything is computed

# %%
import dask
def fake_data():
    raise ValueError("no no no!")
    
value = dask.delayed(fake_data)()
shape = ds.ugos.shape
array = da.from_delayed(value, shape, dtype=float)

ds_fake = ds.copy()
ds_fake.ugos.data = array
ds_fake.vgos.data = array

# %%
ds_fake
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440, time: 11)
# Coordinates:
#     crs        int32 ...
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 0.125 0.375 0.625 0.875 ... 359.4 359.6 359.9
#   * time       (time) datetime64[ns] 1993-01-01 1993-01-02 ... 1993-01-11
# Data variables:
#     ugos       (time, latitude, longitude) float64 dask.array<chunksize=(11, 720, 1440), meta=np.ndarray>
#     vgos       (time, latitude, longitude) float64 dask.array<chunksize=(11, 720, 1440), meta=np.ndarray>
# Attributes:
#     Conventions:                     CF-1.6
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     cdm_data_type:                   Grid
#     comment:                         Sea Surface Height measured by Altimetry...
#     contact:                         servicedesk.cmems@mercator-ocean.eu
#     creator_email:                   servicedesk.cmems@mercator-ocean.eu
# ...

# %%
# ds_fake.vgos.load() # This works

# %%
variables = {'U': 'ugos', 'V': 'vgos'}
dimensions = {'lon': 'longitude', 'lat': 'latitude', 'time': 'time'}
#     ds = ds.isel(time=slice(0,10))
fset_fake = FieldSet.from_xarray_dataset(ds_fake, variables, dimensions)
fset_fake.add_periodic_halo(zonal=True, meridional=False, halosize=2)
# Out:
# WARNING: Casting depth data to np.float32
# WARNING: Casting field data to np.float32

# %%
fset_real = FieldSet.from_xarray_dataset(ds, variables, dimensions)
fset_real.add_periodic_halo(zonal=True, meridional=False, halosize=2)

# %%
# without any of the fancy reprogramming...

# %%
def periodicBC(particle, fieldset, time):
    if particle.lon < 0:
        particle.lon += 360
    elif particle.lon > 360:
        particle.lon -= 360

import inspect
_funccode = inspect.getsource(periodicBC.__code__) 
_funcvars = list(periodicBC.__code__.co_varnames)

# %%
# def periodicBC(particle, fieldset, time):
#     if particle.lon < 0:
#         particle.lon += 360
#     elif particle.lon > 360:
#         particle.lon -= 360
        
def get_ds_from_pset(pset):
    pids = da.asarray(pset.particle_data['id'])
    times = da.asarray(pset.particle_data['time'])
    lats = da.asarray(pset.particle_data['lat'])
    lons = da.asarray(pset.particle_data['lon'])
    
    ds = xr.Dataset(data_vars={"times": (("pid", ), times),
                               "lats": (("pid", ), lats),
                               "lons": (("pid", ), lons)},
                    coords={"pid": pids})
    return ds

# %%
fset=fset_real

lats = np.linspace(10,40, 50)
lons = np.linspace(50,100, 50)
runtime = delta(days=2)
outputdt =delta(hours=12)
pset = ParticleSet(fset, JITParticle, lon=lons, lat=lats)

Niter = int(np.ceil(runtime / outputdt))
ds_list = [get_ds_from_pset(pset)]

from parcels.kernel import Kernel

periodic_kernel = Kernel(fieldset=fset, ptype=JITParticle.getPType(),
                         funcname="periodicBC", pyfunc=periodicBC,
                         funccode=_funccode, funcvars=_funcvars)

kernel = pset.Kernel(AdvectionRK4) + periodic_kernel
for n in range(Niter):
    pset.execute(kernel,
                 runtime=outputdt, dt=outputdt)
    ds_list.append(get_ds_from_pset(pset))

output_ds = xr.concat(ds_list, dim="time")

# Niter = int(np.ceil(runtime / outputdt))
# ds_list = [get_ds_from_pset(pset)]
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~/code/parcels/parcels/compiler.py in compile(self, src, obj, log)
#      51             try:
# ---> 52                 subprocess.check_call(cc, stdout=logfile, stderr=logfile)
#      53             except OSError:
#
# ~/miniconda/envs/py3_parcels/lib/python3.6/subprocess.py in check_call(*popenargs, **kwargs)
#     310             cmd = popenargs[0]
# --> 311         raise CalledProcessError(retcode, cmd)
#     312     return 0
#
# CalledProcessError: Command '['gcc', '-Wall', '-fPIC', '-I/Users/juliusbusecke/code/parcels/parcels/include', '-g', '-O3', '-m64', '-o', '/var/folders/nn/jxxm7c6n58b9s78_130zkpzr0000gn/T/parcels-501/72a70681a9e621a2fecbba060efd4dda_0.so', '/var/folders/nn/jxxm7c6n58b9s78_130zkpzr0000gn/T/parcels-501/72a70681a9e621a2fecbba060efd4dda_0.c', '-shared', '-m64']' returned non-zero exit status 1.
#
# ...

# %%
pset.execute()

# %%
from dask import array as da
def get_ds_from_pset(pset):
#     ids = da.asarray([p.id for p in pset.particles])
#     times = da.asarray([p.time for p in pset.particles])
#     lats = da.asarray([p.lat for p in pset.particles])
#     lons = da.asarray([p.lon for p in pset.particles])
    pids = da.asarray(pset.particle_data['id'])
    times = da.asarray(pset.particle_data['time'])
    lats = da.asarray(pset.particle_data['lat'])
    lons = da.asarray(pset.particle_data['lon'])
    
    ds = xr.Dataset(data_vars={"times": (("pid", ), times),
                               "lats": (("pid", ), lats),
                               "lons": (("pid", ), lons)},
                    coords={"pid": pids})
    return ds

# %%
def run_parcels(ds, runtime, outputdt, lon_bds, lat_bds, npart, seed):
    from parcels import FieldSet, AdvectionRK4, ParticleSet, JITParticle, ParticleFile
    from parcels import plotTrajectoriesFile
    import numpy as np
    import xarray as xr
    import gcsfs
    from datetime import timedelta as delta

    variables = {'U': 'ugos', 'V': 'vgos'}
    dimensions = {'lon': 'longitude', 'lat': 'latitude', 'time': 'time'}
#     ds = ds.isel(time=slice(0,10))
    fset = FieldSet.from_xarray_dataset(ds, variables, dimensions)
    fset.add_periodic_halo(zonal=True, meridional=False, halosize=2)
    
    np.random.seed(seed)
    lats = np.random.uniform(min(lat_bds), max(lat_bds), npart)
    lons = np.random.uniform(min(lon_bds), max(lon_bds), npart)
    pset = ParticleSet(fset, JITParticle, lon=lons, lat=lats)

    Niter = int(np.ceil(runtime / outputdt))
    ds_list = [get_ds_from_pset(pset)]
      
    from parcels.kernel import Kernel

    periodic_kernel = Kernel(fieldset=fset, ptype=JITParticle.getPType(),
                             funcname="periodicBC", pyfunc=periodicBC,
                             funccode=_funccode, funcvars=_funcvars)
        
    kernel = pset.Kernel(AdvectionRK4) + periodic_kernel
    for n in range(Niter):
        pset.execute(kernel,
                     runtime=outputdt, dt=outputdt)
        ds_list.append(get_ds_from_pset(pset))
    
    output_ds = xr.concat(ds_list, dim="time")
    
    return output_ds
